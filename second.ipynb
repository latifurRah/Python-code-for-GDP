# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("cleanned_data2.csv")
df.head(10)
df=df.drop(labels=[0,1,2,3,4],axis=0)
df.head(10)
# Out:
#     Time  Exports     FCE   GDP  G_F_C_E  D_Savings  G_Savings  Imports  \
# 5   1976     4.75  102.98  5.66     4.07      -2.98      -0.84    17.64
# 6   1977     7.04   93.82  2.67     5.09       6.18      10.04    12.38
# 7   1978     5.56   98.38  7.07     4.88       1.62       5.70    15.48
# 8   1979     6.11   98.48  4.80     6.28       1.52       7.08    15.80
# 9   1980     5.49   97.95  0.82     6.14       2.05       8.33    17.88
# 10  1981     5.13   85.16  7.23     4.39      14.84      21.14    14.12
# 11  1982     5.08   85.22  2.13     4.43      14.78      23.53    15.53
# 12  1983     5.60   87.95  3.88     4.31      12.05      23.10    14.71
# 13  1984     3.40   93.22  4.80     4.34       6.78      16.29    13.42
# 14  1985     5.38   85.49  3.34     4.03      14.51      21.52    12.84
#
#     Inflation  Remittances     U  Reserve  FDII  FDIO  Industry
# 5      -17.63         0.19  3.17    14.49  0.05   0.0     14.45
# 6       -3.21         0.82  3.17    10.36  0.07   0.0     16.73
# 7       25.62         0.87  3.17    11.39  0.06   0.0     14.31
# 8       12.56         1.10  3.17    13.94 -0.05   0.0     15.69
# 9       17.56         1.87  3.17     8.71  0.05   0.0     20.12
# 10       9.89         1.88  3.17     3.79  0.03   0.0     19.81
# 11       9.86         2.84  3.17     4.22  0.04   0.0     20.04
# 12       8.49         3.65  3.17    10.21  0.00   0.0     20.87
# 13       7.88         2.65  2.04     7.36 -0.00   0.0     21.43
# 14      18.50         2.26  2.02     5.45 -0.03   0.0     20.32

# %%
list(df.columns)
# Out:
# ['Time',
#  'Exports',
#  'FCE',
#  'GDP',
#  'G_F_C_E',
#  'D_Savings',
#  'G_Savings',
#  'Imports',
#  'Inflation',
#  'Remittances',
#  'U',
#  'Reserve',
#  'FDII',
#  'FDIO',
#  'Industry']

# %%
#correlation matrix

# %%
cor=df.corr()
cor
# Out:
#                  Time   Exports       FCE       GDP   G_F_C_E  D_Savings  \
# Time         1.000000  0.808371 -0.902004  0.585986  0.621491   0.902004
# Exports      0.808371  1.000000 -0.672830  0.556757  0.486389   0.672830
# FCE         -0.902004 -0.672830  1.000000 -0.464394 -0.416932  -1.000000
# GDP          0.585986  0.556757 -0.464394  1.000000  0.373390   0.464394
# G_F_C_E      0.621491  0.486389 -0.416932  0.373390  1.000000   0.416932
# D_Savings    0.902004  0.672830 -1.000000  0.464394  0.416932   1.000000
# G_Savings    0.904531  0.821159 -0.936464  0.473110  0.388402   0.936464
# Imports      0.644397  0.902256 -0.426243  0.525565  0.444442   0.426243
# Inflation   -0.048398 -0.060352 -0.025365 -0.012199  0.112974   0.025365
# Remittances  0.754707  0.907061 -0.650405  0.434067  0.346334   0.650405
# U            0.409284  0.494023 -0.303457  0.350889  0.453546   0.303457
# Reserve      0.797161  0.642965 -0.626713  0.523561  0.637822   0.626713
# FDII         0.717252  0.886091 -0.576826  0.531119  0.427790   0.576826
# FDIO         0.382682  0.670980 -0.260482  0.287360  0.119999   0.260482
# Industry     0.920066  0.576148 -0.855616  0.487031  0.632532   0.855616
#
#              G_Savings   Imports  Inflation  Remittances         U   Reserve  \
# Time          0.904531  0.644397  -0.048398     0.754707  0.409284  0.797161
# Exports       0.821159  0.902256  -0.060352     0.907061  0.494023  0.642965
# FCE          -0.936464 -0.426243  -0.025365    -0.650405 -0.303457 -0.626713
# GDP           0.473110  0.525565  -0.012199     0.434067  0.350889  0.523561
# G_F_C_E       0.388402  0.444442   0.112974     0.346334  0.453546  0.637822
# D_Savings     0.936464  0.426243   0.025365     0.650405  0.303457  0.626713
# G_Savings     1.000000  0.638185   0.035943     0.867417  0.360380  0.663121
# Imports       0.638185  1.000000  -0.026616     0.856799  0.430126  0.586985
# Inflation     0.035943 -0.026616   1.000000    -0.003161 -0.028615  0.065383
# Remittances   0.867417  0.856799  -0.003161     1.000000  0.417130  0.608251
# U             0.360380  0.430126  -0.028615     0.417130  1.000000  0.441657
# Reserve       0.663121  0.586985   0.065383     0.608251  0.441657  1.000000
# FDII          0.749359  0.866738  -0.007118     0.875791  0.473088  0.705397
# FDIO          0.497206  0.740109   0.035209     0.724776  0.319594  0.358499
# Industry      0.797430  0.433238  -0.002110     0.551893  0.308622  0.776463
#
#                  FDII      FDIO  Industry
# Time         0.717252  0.382682  0.920066
# Exports      0.886091  0.670980  0.576148
# FCE         -0.576826 -0.260482 -0.855616
# GDP          0.531119  0.287360  0.487031
# G_F_C_E      0.427790  0.119999  0.632532
# D_Savings    0.576826  0.260482  0.855616
# G_Savings    0.749359  0.497206  0.797430
# Imports      0.866738  0.740109  0.433238
# Inflation   -0.007118  0.035209 -0.002110
# Remittances  0.875791  0.724776  0.551893
# U            0.473088  0.319594  0.308622
# Reserve      0.705397  0.358499  0.776463
# FDII         1.000000  0.675104  0.501674
# FDIO         0.675104  1.000000  0.207863
# Industry     0.501674  0.207863  1.000000

# %%
#Heatmap
plt.figure(figsize=(8,8))
           
                
annot=True
hemap=sns.heatmap(cor,vmin=-1,vmax=1,center=0,annot=annot)
hemap
# Out:
# <Axes: >

# %% [markdown]
# mask_ut=np.triu(np.ones(cor.shape))
# mask_ut

# %%
mask = np.triu(np.ones_like(df.corr()))

# %%
#upper trangular correlation matrix
dataplot = sns.heatmap(df.corr(), mask=mask,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mask = np.tril(np.ones_like(df.corr()))

# %%
#upper trangular correlation matrix
dataplot = sns.heatmap(df.corr(), mask=mask,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Multicolinearity Checking

# %%
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor
#Desgin matrix

y, X = dmatrices("GDP~Exports+FCE+G_F_C_E+D_Savings+G_Savings+Imports+Inflation+Remittances+U+Reserve+FDII+FDIO+Industry", data=df, return_type='dataframe')

#create DataFrame to hold VIF values
vif_df = pd.DataFrame()
vif_df['variable'] = X.columns 

#calculate VIF for each predictor variable 
vif_df['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

#view VIF for each predictor variable 
print(vif_df)
# Out:
#        variable         VIF
# 0     Intercept    0.000000
# 1       Exports   18.322221
# 2           FCE         inf
# 3       G_F_C_E    3.829561
# 4     D_Savings         inf
# 5     G_Savings  289.937250
# 6       Imports   13.842322
# 7     Inflation    1.425520
# 8   Remittances   85.594292
# 9             U    1.548667
# 10      Reserve    5.267267
# 11         FDII    8.875593
# 12         FDIO    2.998310
# 13     Industry   14.101558

# %% [markdown]
# Multiple linear regression

# %%
x=df.drop("GDP",axis=1)
x1=df.Time

y=df.GDP
x.shape
# Out:
# (47, 14)

# %%
# mymodel = np.poly1d(np.polyfit(x1, y, 3))

# myline = np.linspace(0,10,52)
plt.scatter(x1,y)
# plt.plot(myline, mymodel(myline))
plt.show()

# %%
mymodel = np.poly1d(np.polyfit(x1, y, 3))

myline = np.linspace(-15,10,52)
plt.scatter(x1,y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
print(y)
# Out:
# 5     5.66
# 6     2.67
# 7     7.07
# 8     4.80
# 9     0.82
# 10    7.23
# 11    2.13
# 12    3.88
# 13    4.80
# 14    3.34
# 15    4.17
# 16    3.77
# 17    2.42
# 18    2.84
# 19    5.62
# 20    3.49
# 21    5.44
# 22    4.71
# 23    3.89
# 24    5.12
# 25    4.52
# 26    4.49
# 27    5.18
# 28    4.67
# 29    5.29
# 30    5.08
# 31    3.83
# 32    4.74
# 33    5.24
# 34    6.54
# 35    6.67
# 36    7.06
# 37    6.01
# 38    5.05
# 39    5.57
# 40    6.46
# 41    6.52
# 42    6.01
# 43    6.06
# 44    6.55
# 45    7.11
# 46    6.59
# 47    7.32
# 48    7.88
# 49    3.45
# 50    6.94
# 51    7.10
# Name: GDP, dtype: float64

# %%
plt.figure(figsize=(6,6))
# plt.title("GDP of Bangladesh")
plt.xlabel("Time")
plt.ylabel("GDP")
plt.plot(df["Time"],df["GDP"],color="red")

# %%
df.shape
# Out:
# (47, 15)

# %%
from sklearn import model_selection 
from sklearn.linear_model import LinearRegression
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.3,random_state=42)

# %%
lm=LinearRegression()
lm.fit(x,y)
print(lm.intercept_)
print(lm.coef_)
# Out:
# -269.18754402970234
# [ 0.13550449 -0.00286253  0.0594825  -0.5856726  -0.0594825   0.10281062
#   0.20261565  0.01796681 -0.64948433  0.2820556   0.00140822  0.67133992
#  -1.07889786 -0.09129107]

# %%
xtrain.shape,xtest.shape
# Out:
# ((32, 14), (15, 14))

# %%
ytrain.shape,ytest.shape
# Out:
# ((32,), (15,))

# %%
lm.score(xtest,ytest)
# Out:
# 0.5290653159082717

# %%
from sklearn.metrics import explained_variance_score

# %%
y_predict=lm.predict(xtest)

# %%
y_predict[:4]
# Out:
# array([5.27142269, 7.2441158 , 4.67289197, 5.92559392])

# %%
print(explained_variance_score(ytest,y_predict))
# Out:
# 0.5706323506778558

# %%
x=df.drop("GDP",axis=1)
y=df.GDP
import statsmodels.formula.api as smf
# lm=smf.ols(formula="GDP~Time+Exports+FCE+G_F_C_E+D_Savings+G_Savings+Imports+Inflation+Remittances+U+Reserve+FDII+FDIO+Industry",data=df).fit()
lm=smf.ols(formula='y~x',data=df).fit()
lm.conf_int()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.279
# Method:                 Least Squares   F-statistic:                     2.370
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):             0.0226
# Time:                        12:30:48   Log-Likelihood:                -72.187
# No. Observations:                  47   AIC:                             172.4
# Df Residuals:                      33   BIC:                             198.3
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0538      0.044     -1.210      0.235      -0.144       0.037
# x[0]           0.1355      0.107      1.263      0.215      -0.083       0.354
# x[1]          -0.0029      0.200     -0.014      0.989      -0.409       0.403
# x[2]          -2.6319      2.103     -1.251      0.220      -6.911       1.647
# x[3]          -0.5857      0.613     -0.955      0.346      -1.833       0.662
# x[4]          -2.7508      2.352     -1.169      0.251      -7.537       2.035
# x[5]           0.1028      0.404      0.254      0.801      -0.719       0.925
# x[6]           0.2026      0.169      1.200      0.239      -0.141       0.546
# x[7]           0.0180      0.034      0.523      0.605      -0.052       0.088
# x[8]          -0.6495      0.798     -0.813      0.422      -2.274       0.975
# x[9]           0.2821      0.340      0.829      0.413      -0.410       0.974
# x[10]          0.0014      0.022      0.064      0.949      -0.043       0.046
# x[11]          0.6713      1.190      0.564      0.576      -1.749       3.092
# x[12]         -1.0789      4.364     -0.247      0.806      -9.957       7.799
# x[13]         -0.0913      0.240     -0.381      0.706      -0.579       0.396
# ==============================================================================
# Omnibus:                        2.905   Durbin-Watson:                   2.578
# Prob(Omnibus):                  0.234   Jarque-Bera (JB):                2.095
# Skew:                           0.192   Prob(JB):                        0.351
# Kurtosis:                       3.961   Cond. No.                     1.54e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.99e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
lm=smf.ols(formula="GDP~Industry+Reserve",data=df).fit()
lm.rsquared
# Out:
# 0.2904370100711192

# %% [markdown]
# Ridge regression model

# %%
from sklearn.linear_model import Ridge

# %%
#Ridge Regression Model
from math import sqrt
from sklearn.metrics import r2_score,mean_squared_error
ridgeReg = Ridge(alpha=0.001)

ridgeReg.fit(xtrain,ytrain)
print(sqrt(mean_squared_error(ytrain, ridgeReg.predict(xtrain))))
print(sqrt(mean_squared_error(ytest, ridgeReg.predict(xtest))))
print('R2 Value/Coefficient of Determination: {}'.format(ridgeReg.score(xtest, ytest)))
# Out:
# 0.8030270036685785
# 2.647468423926687
# R2 Value/Coefficient of Determination: -1.0653970065957132

# %%
plt.figure(figsize=(6,4))
# plt.title("GDP of Bangladesh")
plt.xlabel("Time")
plt.ylabel("GDP")
plt.plot(xtrain["Time"],ytrain,color="red")
plt.plot(xtest["Time"],ytest,color="black")
# plt.plot(xtest["Time"],ypredr,color="green")

# %% [markdown]
# # Lasso regression model

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import RepeatedKFold

# %%
xtrain.sample(5),ytrain.sample(5)
# Out:
# (    Time  Exports     FCE  G_F_C_E  D_Savings  G_Savings  Imports  Inflation  \
#  5   1976     4.75  102.98     4.07      -2.98      -0.84    17.64     -17.63
#  39  2010    16.02   79.19     5.08      20.81      38.78    21.78       7.14
#  28  1999    11.76   81.27     5.04      18.73      26.66    16.63       3.78
#  6   1977     7.04   93.82     5.09       6.18      10.04    12.38      -3.21
#  16  1987     4.99   85.90     4.14      14.10      22.63    11.70      11.12
#
#      Remittances     U  Reserve  FDII  FDIO  Industry
#  5          0.19  3.17    14.49  0.05  0.00     14.45
#  39         9.41  3.38    42.06  1.07  0.06     24.96
#  28         3.52  3.17     9.94  0.35  0.00     22.38
#  6          0.82  3.17    10.36  0.07  0.00     16.73
#  16         3.08  3.17     9.00  0.01  0.00     19.60  ,
#  7     7.07
#  46    6.59
#  42    6.01
#  12    3.88
#  36    7.06
#  Name: GDP, dtype: float64)

# %%
# lassoreg = Lasso(alpha=.01)
# Lasso.fit(xtrain,ytrain)

# %%
print(sqrt(mean_squared_error(ytrain, Lasso.predict(xtrain))))
print(sqrt(mean_squared_error(ytest, Lasso.predict(xtest))))
print('R2 Value/Coefficient of Determination: {}'.format(Lasso.score(xtest, ytest)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(sqrt(mean_squared_error(ytrain, Lasso.predict(xtrain))))
#       2 print(sqrt(mean_squared_error(ytest, Lasso.predict(xtest))))
#       3 print('R2 Value/Coefficient of Determination: {}'.format(Lasso.score(xtest, ytest)))
#
# TypeError: LinearModel.predict() missing 1 required positional argument: 'X'

# %% [markdown]
# Support vector regression

# %%
from sklearn.svm import SVR
model_svr=SVR(kernel="rbf")
model_svr.fit(xtrain,ytrain)

# %%
model_svr.score(xtest,ytest)

# %%
y_pred=model_svr.predict(xtest)
print(y_pred[:4])
r2_score(ytest,y_pred)

# %%
plt.figure(figsize=(6,6))
plt.title=("GDP of Bangladesh")
plt.xlabel("Time")
plt.ylabel("GDP")
plt.plot(xtrain["Time"],ytrain,color="green")

# %%
# from sklearn.svm import SVC
# model_svr=SVC()
# model_svr.fit(xtrain,ytrain)
print(type(xtrain))

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.3,random_state=0)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)

# %%
from sklearn.ensemble import RandomForestRegressor
RFreg=RandomForestRegressor(n_estimators=5,max_depth=10,min_samples_split=4)
RFreg.fit(xtrain,ytrain)

# %%
output=pred_RFreg=RFreg.predict(xtest)
output
print(pred_RFreg[:4])

# %%
output[1]

# %%
ytest[:1]

# %%
RFreg.score(xtest,ytest)

# %% [markdown]
# R_square

# %%
from sklearn import metrics
metrics.r2_score(ytest,pred_RFreg)

# %% [markdown]
# GradientBoostinClassifire

# %%
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_squared_error

# %%
#Instantiate Gradient Boosting Regressor
gbc = GradientBoostingRegressor(n_estimators=300,
                                 learning_rate=0.05,
                                 random_state=42,
                                 max_features=5 )

# %%
#fit
gbc.fit(xtrain, ytrain)
 
# Predict on test set
pred_y = gbc.predict(xtest)
print("Prediction of GDP",pred_y[:4])

# %%
# test set RMSE
test_rmse = mean_squared_error(ytest, pred_y) ** (1 / 2)
 
# Print rmse
print('Root mean Square error: {:.2f}'.format(test_rmse))

# %%
###Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor
adr = AdaBoostRegressor()
adr.fit(xtrain, ytrain)
y_pred = adr.predict(xtest)
print(y_pred[:4])
print("AdaBoost - R2: ",
      r2_score(ytest, y_pred))

# %% [markdown]
# TIME SERIES

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import math
from datetime import datetime as dt
# %matplotlib inline
from statsmodels.tsa.stattools import adfuller,acf,pacf
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model.ARIMA 
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=10,6
import warnings
warnings.filterwarnings('ignore')

# %%
###Time series analaysis between time and gdp

# %%
df1=df.reindex(columns=['Time','GDP'])
df1.head(10)
print(df1.shape)
# Out:
# (47, 2)

# %%
# result = seasonal_decompose(df1['GDP'], model ='multiplicative')
# result.plot()

# %%
plt.plot(df1['Time'],df1['GDP'])
# plt.title('GDP of Bangladesh')

plt.show()

# %%
# df1['Time']=df1['Time'].apply(lambda x:dt(int(x[:4]),int(x[5:]),15))
# df1=df1.set_index('Time')

# %%
print(df1.head())
# Out:
#    Time   GDP
# 5  1976  5.66
# 6  1977  2.67
# 7  1978  7.07
# 8  1979  4.80
# 9  1980  0.82

# %%
ts=df1['GDP']

# %%
plt.plot(ts)

# %%
ts_log=np.log(ts)
(ts_log)
plt.plot(ts_log)

# %%
df1.head(10)
df1.min()
# Out:
# Time    1976.00
# GDP        0.82
# dtype: float64

# %% [markdown]
# ## Stationary check

# %%
def test_stationarity(timeseries):
    rolmean=timeseries.rolling(window=52,center=False).mean()
    rolestd=timeseries.rolling(window=52,center=False).std()
    orig=plt.plot(timeseries,color='blue',label='Original')
    mean=plt.plot(rolmean,color='red',label='Rolling Mean')
    std=plt.plot(rolestd,color='green',label='Rolling std')
    plt.legend(loc='best')
    # plt.title('Rolling mean & rolling std')
    plt.show(block=False)
    print('Result of Dickey fuller test:')
    dftest=adfuller(timeseries,autolag='AIC')
    dfoutput=pd.Series(dftest[0:4],index=['Test statistic','P-value',"#lags Used",'Number of obs. used'])
    for key,value in dftest[4].items():
        dfoutput['critical value(%s)'%key]=value
        print(dfoutput)

# %%
test_stationarity(df1['GDP'])
# Out:
# Result of Dickey fuller test:
# Test statistic         -0.296979
# P-value                 0.925931
# #lags Used              5.000000
# Number of obs. used    41.000000
# critical value(1%)     -3.600983
# dtype: float64
# Test statistic         -0.296979
# P-value                 0.925931
# #lags Used              5.000000
# Number of obs. used    41.000000
# critical value(1%)     -3.600983
# critical value(5%)     -2.935135
# dtype: float64
# Test statistic         -0.296979
# P-value                 0.925931
# #lags Used              5.000000
# Number of obs. used    41.000000
# critical value(1%)     -3.600983
# critical value(5%)     -2.935135
# critical value(10%)    -2.605963
# dtype: float64

# %%
movingAverage=ts_log.rolling(window=12).mean()
movingstd=ts_log.rolling(window=12).std()
plt.plot(ts_log,color='blue',label='Original')
plt.plot(movingAverage,color='red',label='MovingAverge')
plt.legend(loc='best')
plt.show()

# %%
#difference
ts_log_mv_diff=ts_log-movingAverage
print(ts_log_mv_diff.head(12))
ts_log_mv_diff.dropna(inplace=True)
ts_log_mv_diff.head(10)
# Out:
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16    0.021967
# Name: GDP, dtype: float64
# 16    0.021967
# 17   -0.350536
# 18   -0.195644
# 19    0.506011
# 20    0.056141
# 21    0.342333
# 22    0.233954
# 23   -0.007515
# 24    0.244120
# 25    0.124486
# Name: GDP, dtype: float64

# %%
test_stationarity(ts_log_mv_diff)
# Out:
# Result of Dickey fuller test:
# Test statistic         -5.466628
# P-value                 0.000002
# #lags Used              0.000000
# Number of obs. used    35.000000
# critical value(1%)     -3.632743
# dtype: float64
# Test statistic         -5.466628
# P-value                 0.000002
# #lags Used              0.000000
# Number of obs. used    35.000000
# critical value(1%)     -3.632743
# critical value(5%)     -2.948510
# dtype: float64
# Test statistic         -5.466628
# P-value                 0.000002
# #lags Used              0.000000
# Number of obs. used    35.000000
# critical value(1%)     -3.632743
# critical value(5%)     -2.948510
# critical value(10%)    -2.613017
# dtype: float64

# %%
plt.plot(np.arange(0,11),acf(ts_log_mv_diff,nlags=10))
plt.axhline(y=0,linestyle='--',color="gray")
plt.axhline(y=-7.96/np.sqrt(len(ts_log_mv_diff)),linestyle='--',color='gray')
plt.axhline(y=7.96/np.sqrt(len(ts_log_mv_diff)),linestyle='--',color='gray')
# plt.title('autocorreltion function')
plt.show()

# %%
plt.plot(np.arange(0,11),pacf(ts_log_mv_diff,nlags=10))
plt.axhline(y=0,linestyle='--',color="gray")
plt.axhline(y=-7.96/np.sqrt(len(ts_log_mv_diff)),linestyle='--',color='gray')
plt.axhline(y=7.96/np.sqrt(len(ts_log_mv_diff)),linestyle='--',color='gray')
# plt.title('Partial autocorreltion function')
plt.show()

# %%
from pmdarima import auto_arima
  
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
  
# Fit auto_arima function to AirPassengers dataset
stepwise_fit = auto_arima(df['GDP'], start_p = 1, start_q = 1,
                          max_p = 3, max_q = 3, m = 12,
                          start_P = 0, seasonal = True,
                          d = None, D = 1, trace = True,
                          error_action ='ignore',   # we don't want to know if an order does not work
                          suppress_warnings = True,  # we don't want convergence warnings
                          stepwise = True)           # set to stepwise
  
# To print the summary
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=140.843, Time=0.58 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=138.105, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=138.898, Time=0.23 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=138.997, Time=0.22 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=143.380, Time=0.04 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=137.950, Time=0.14 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=139.949, Time=0.41 sec
#  ARIMA(0,0,0)(1,1,1)[12] intercept   : AIC=139.949, Time=0.25 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=138.129, Time=0.11 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=141.949, Time=0.53 sec
#  ARIMA(0,0,1)(1,1,0)[12] intercept   : AIC=139.046, Time=0.23 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=140.889, Time=0.69 sec
#  ARIMA(0,0,0)(1,1,0)[12]             : AIC=145.377, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(1,1,0)[12] intercept
# Total fit time: 3.521 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 SARIMAX Results
# ================================================================================
# Dep. Variable:                        y   No. Observations:                   47
# Model:             SARIMAX(1, 1, 0, 12)   Log Likelihood                 -65.975
# Date:                  Tue, 05 Sep 2023   AIC                            137.950
# Time:                          12:36:01   BIC                            142.616
# Sample:                               0   HQIC                           139.560
#                                    - 47
# Covariance Type:                    opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.0961      0.376      2.918      0.004       0.360       1.832
# ar.S.L12      -0.3222      0.223     -1.447      0.148      -0.759       0.114
# sigma2         2.4462      0.600      4.080      0.000       1.271       3.621
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.00   Jarque-Bera (JB):                 3.62
# Prob(Q):                              0.32   Prob(JB):                         0.16
# Heteroskedasticity (H):               0.33   Skew:                            -0.71
# Prob(H) (two-sided):                  0.07   Kurtosis:                         3.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model = ARIMA(ts_log, order=(1,1,1)) 
results_ARIMA = model.fit(disp=-1)
plt.plot(ts_log_mv_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'%(((results_ARIMA.fittedvalues[1:]-ts_log_mv_diff)**2).mean()))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 model = ARIMA(ts_log, order=(1,1,1))
#       2 results_ARIMA = model.fit(disp=-1)
#       3 plt.plot(ts_log_mv_diff)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
predictions_ARIMA_diff.head()
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_diff_cumsum.head()
predictions_ARIMA_log = pd.Series(ts_log.ix[0], index=ts_log.index)
predictions_ARIMA_log 
predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(ts)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(((predictions_ARIMA-ts)**2)/(ts)).mean())

# %% [markdown]
# ## Train Test Split

# %%
plt.bar(range(numof_lags),pacf_vals2[:numof_lags])

# %%
from statsmodels.tsa.arima_model import ARMA
