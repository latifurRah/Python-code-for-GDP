# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Import data frame

# %%
df=pd.read_csv("GDP_data.csv",index_col=0)
#df_pd.rename(columns={'GDP growth':"GDP"},inplace=True)
df.head()
# Out:
#       Exports     FCE    GDP  G_F_C_E  D_Savings  G_Savings  Imports  \
# Time
# 1971     6.29   96.21  -5.48      NaN       3.79        NaN    10.73
# 1972     5.67  103.36 -13.97      NaN      -3.36        NaN    13.73
# 1973     6.54   96.60   3.33     3.94       3.40        NaN    11.86
# 1974     3.70   99.27   9.59     4.64       0.73        NaN    10.35
# 1975     2.90   99.06  -4.09     3.16       0.94        NaN     8.10
#
#       Inflation  Remittances   U  Reserve   FDII  FDIO  Industry
# Time
# 1971       2.96          NaN NaN      NaN    NaN   NaN      7.68
# 1972       4.40          NaN NaN   184.62  0.001   NaN      6.06
# 1973      61.41          NaN NaN    28.76  0.029   NaN     12.11
# 1974      44.54          NaN NaN    10.99  0.018   NaN     13.37
# 1975      80.57          NaN NaN     8.82  0.008   NaN     11.61

# %%
df.shape
df["FDIO"].fillna(0,inplace=True)
# G_F_C_E fill null by the mean

x=df["G_F_C_E"].mean()
df["G_F_C_E"].fillna(x,inplace=True)
## G_Savings null values replace by their mean
x=df["G_Savings"].mean()
df["G_Savings"].fillna(x,inplace=True)
x=df["Remittances"].min()
df["Remittances"].fillna(x,inplace=True)

#Reserve	replace null value by mean value
x=df["Reserve"].mean()
df["Reserve"].fillna(x,inplace=True)
#Stocks null value replace by mean value
x=df["U"].mean()
df["U"].fillna(x,inplace=True)
#Foregin direct investment inflow
df["FDII"].fillna(0,inplace=True)

df.head(5)
# Out:
#       Exports     FCE    GDP  G_F_C_E  D_Savings  G_Savings  Imports  \
# Time
# 1971     6.29   96.21  -5.48   4.9474       3.79  27.048511    10.73
# 1972     5.67  103.36 -13.97   4.9474      -3.36  27.048511    13.73
# 1973     6.54   96.60   3.33   3.9400       3.40  27.048511    11.86
# 1974     3.70   99.27   9.59   4.6400       0.73  27.048511    10.35
# 1975     2.90   99.06  -4.09   3.1600       0.94  27.048511     8.10
#
#       Inflation  Remittances      U   Reserve   FDII  FDIO  Industry
# Time
# 1971       2.96         0.19  3.174   26.7162  0.000   0.0      7.68
# 1972       4.40         0.19  3.174  184.6200  0.001   0.0      6.06
# 1973      61.41         0.19  3.174   28.7600  0.029   0.0     12.11
# 1974      44.54         0.19  3.174   10.9900  0.018   0.0     13.37
# 1975      80.57         0.19  3.174    8.8200  0.008   0.0     11.61

# %%
#Correlation matrix
df = round(df,2)
df
# Out:
#       Exports     FCE    GDP  G_F_C_E  D_Savings  G_Savings  Imports  \
# Time
# 1971     6.29   96.21  -5.48     4.95       3.79      27.05    10.73
# 1972     5.67  103.36 -13.97     4.95      -3.36      27.05    13.73
# 1973     6.54   96.60   3.33     3.94       3.40      27.05    11.86
# 1974     3.70   99.27   9.59     4.64       0.73      27.05    10.35
# 1975     2.90   99.06  -4.09     3.16       0.94      27.05     8.10
# 1976     4.75  102.98   5.66     4.07      -2.98      -0.84    17.64
# 1977     7.04   93.82   2.67     5.09       6.18      10.04    12.38
# 1978     5.56   98.38   7.07     4.88       1.62       5.70    15.48
# 1979     6.11   98.48   4.80     6.28       1.52       7.08    15.80
# FCE         -0.713690  1.000000 -0.529609 -0.471366  -1.000000  -0.762974
# GDP          0.405891 -0.529609  1.000000  0.273247   0.529609   0.194968
# G_F_C_E      0.528712 -0.471366  0.273247  1.000000   0.471366   0.348429
# D_Savings    0.713690 -1.000000  0.529609  0.471366   1.000000   0.762974
# G_Savings    0.765262 -0.762974  0.194968  0.348429   0.762974   1.000000
# Imports      0.911694 -0.545846  0.409828  0.512537   0.545846   0.574853
# Inflation   -0.279739  0.335627 -0.148415 -0.340051  -0.335627   0.015649
# Remittances  0.912736 -0.730363  0.426900  0.413796   0.730363   0.774868
# U            0.460597 -0.247561  0.144948  0.407052   0.247561   0.360380
# Reserve      0.320250 -0.124290 -0.383205  0.403998   0.124290   0.437983
# FDII         0.887672 -0.599883  0.366617  0.447075   0.599883   0.724833
# FDIO         0.668391 -0.290487  0.200788  0.149191   0.290487   0.492265
# Industry     0.621271 -0.897257  0.628906  0.592839   0.897257   0.591946
#
#               Imports  Inflation  Remittances         U   Reserve      FDII  \
# Exports      0.911694  -0.279739     0.912736  0.460597  0.320250  0.887672
# FCE         -0.545846   0.335627    -0.730363 -0.247561 -0.124290 -0.599883
# GDP          0.409828  -0.148415     0.426900  0.144948 -0.383205  0.366617
# G_F_C_E      0.512537  -0.340051     0.413796  0.407052  0.403998  0.447075
# D_Savings    0.545846  -0.335627     0.730363  0.247561  0.124290  0.599883
# G_Savings    0.574853   0.015649     0.774868  0.360380  0.437983  0.724833
# Imports      1.000000  -0.325523     0.876628  0.387683  0.303243  0.860699
# Inflation   -0.325523   1.000000    -0.284432 -0.012781 -0.077386 -0.159543
# Remittances  0.876628  -0.284432     1.000000  0.372881  0.234147  0.870733
# U            0.387683  -0.012781     0.372881  1.000000  0.291547  0.457752
# Reserve      0.303243  -0.077386     0.234147  0.291547  1.000000  0.377661
# FDII         0.860699  -0.159543     0.870733  0.457752  0.377661  1.000000
# FDIO         0.718599  -0.073420     0.704198  0.316499  0.195419  0.682176
# Industry     0.551689  -0.336594     0.659963  0.229467  0.121168  0.527015
#
#                  FDIO  Industry
# Exports      0.668391  0.621271
# FCE         -0.290487 -0.897257
# GDP          0.200788  0.628906
# G_F_C_E      0.149191  0.592839
# D_Savings    0.290487  0.897257
# G_Savings    0.492265  0.591946
# Imports      0.718599  0.551689
# Inflation   -0.073420 -0.336594
# Remittances  0.704198  0.659963
# U            0.316499  0.229467
# Reserve      0.195419  0.121168
# FDII         0.682176  0.527015
# FDIO         1.000000  0.244710
# Industry     0.244710  1.000000

# %%
#Heatmap
plt.figure(figsize=(10,10))
           
                
annot=True
hemap=sns.heatmap(cor,vmin=-1,vmax=1,center=0,annot=annot)
hemap
# Out:
# <Axes: >

# %% [markdown]
# ### Multicolinearity checking of the data frame

# %%
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor
#Desgin matrix

y, X = dmatrices("GDP~Exports+FCE+G_F_C_E+D_Savings+G_Savings+Imports+Inflation+Remittances+U+Reserve+FDII+FDIO+Industry", data=df, return_type='dataframe')

#create DataFrame to hold VIF values
vif_df = pd.DataFrame()
vif_df['variable'] = X.columns 

#calculate VIF for each predictor variable 
vif_df['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

#view VIF for each predictor variable 
print(vif_df)
# Out:
#        variable        VIF
# 0     Intercept   0.000000
# 1       Exports  18.072227
# 2           FCE        inf
# 3       G_F_C_E   2.739680
# 4     D_Savings        inf
# 5     G_Savings  11.834026
# 6       Imports  14.822747
# 7     Inflation   2.387766
# 8   Remittances  13.910148
# 9             U   1.498743
# 10      Reserve   2.586768
# 11         FDII   6.726471
# 12         FDIO   2.906181
# 13     Industry  10.195992
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:1781: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\stats\outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)

# %% [markdown]
# ### Multiple linear regression model

# %%
from sklearn.metrics import r2_score,mean_squared_error
from math import sqrt
import numpy as np

# %%
df.shape
list(df.columns)
# Out:
# ['Exports',
#  'FCE',
#  'GDP',
#  'G_F_C_E',
#  'D_Savings',
#  'G_Savings',
#  'Imports',
#  'Inflation',
#  'Remittances',
#  'U',
#  'Reserve',
#  'FDII',
#  'FDIO',
#  'Industry']

# %%
fig,axe=plt.subplots(1,3,sharey=True)#scatter plot 
df.plot(kind="scatter",x="U",y="GDP",ax=axe[0])
df.plot(kind='scatter',x='FCE',y='GDP',ax=axe[1])
# Out:
# <Axes: xlabel='FCE', ylabel='GDP'>

# %%
#Scatter plot using the for loop 
count=0
plt.subplots(figsize=(10, 8))
for i in df.columns:
    plt.subplot(5,3,15)
    sns.scatterplot(data=df,x="GDP",y=i)
    count+=1

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12392\3959204969.py:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(5,3,15)

# %%
#Scatter plot using the for loop 
# x_col="GDP"
# y_columns=['Exports','FCE','G_F_C_E','D_Savings','G_Savings','Imports',
#  'Inflation','Remittances','U','Reserve','FDII','FDIO','Industry']

# for y_col in y_columns:
#     figure=plt.figure
#     ax=plt.gca()
#     ax.scatter(df[x_col],df[y_col])
#     ax.set_xlabel(x_col)
#     ax.set_ylabel(y_col)
#     ax.set_title("{} vs {}".format(x_col, y_col))
# count=1
# plt.subplots(figsize=(10, 8))
# for i in df.columns:
#     plt.subplot(3,2,count)
#     sns.scatterplot(df["GDP"],df[i])
#     count+=1

# plt.show()

# %% [markdown]
# ### Multiple linear regression model

# %%
# fig,ax=plt.subplots(2,4,sharey=True)#scatter plot 
# ax[0,0].scatter(x=df["U"],y=df["GDP"])


"""
ax[i,j].scatter(x=df[i], y=df["GDP "])
"""
# Out:
# '\nax[i,j].scatter(x=df[i], y=df["GDP "])\n'

# %%
featur_cols=['Exports',"FCE","G_F_C_E","D_Savings","G_Savings","Imports","Inflation","Remittances",
             "U","Reserve","FDII","FDIO","Industry"]
x=df[featur_cols]
y=df.GDP


from sklearn import model_selection 
from sklearn.linear_model import LinearRegression
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# ### Download clean data from worksheet

# %%
#df.to_csv("cleanned_data3.csv")

# %%
lm=LinearRegression()
lm.fit(x,y)
print(lm.intercept_)
print(lm.coef_)
# Out:
# -76638695864015.02
# [ 1.00781394e-01  7.66386959e+11 -2.44447708e-01  7.66386959e+11
#  -6.15844727e-02  1.40808105e-01  2.00805664e-02 -3.74755859e-01
#   2.81230927e-01 -6.61621094e-02  2.82196617e+00 -1.80883551e+00
#   4.65240479e-01]

# %% [markdown]
# ### predict four year GDP

# %%
df_new=pd.DataFrame({"GDP":[2023,2024,2025,2026]})
df_new
# Out:
#     GDP
# 0  2023
# 1  2024
# 2  2025
# 3  2026

# %%
# lm.predict(df_new)
predicts=lm.predict(xtest)
predicts
# Out:
# array([4.      , 5.6875  , 7.078125, 3.9375  , 6.25    , 4.296875,
#        3.421875, 6.359375, 1.953125, 5.015625, 4.75    , 3.484375,
#        5.34375 , 3.78125 , 7.59375 , 1.984375])

# %%
print(sqrt(mean_squared_error(ytest,predicts)))
# Out:
# 2.5826069564310883

# %%
import statsmodels.formula.api as smf
lm=smf.ols(formula="GDP~Exports+FCE+G_F_C_E+D_Savings+G_Savings+Imports+Inflation+Remittances+U+Reserve+FDII+FDIO+Industry",data=df).fit()
lm.conf_int()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GDP   R-squared:                       0.710
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     7.973
# Date:                Wed, 09 Aug 2023   Prob (F-statistic):           3.05e-07
# Time:                        20:50:50   Log-Likelihood:                -108.25
# No. Observations:                  52   AIC:                             242.5
# Df Residuals:                      39   BIC:                             267.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.0014      0.002     -0.735      0.467      -0.005       0.003
# Exports         0.1014      0.270      0.375      0.710      -0.446       0.648
# FCE            -0.0431      0.042     -1.016      0.316      -0.129       0.043
# G_F_C_E        -0.2456      0.772     -0.318      0.752      -1.806       1.315
# D_Savings      -0.1004      0.175     -0.575      0.569      -0.454       0.253
# G_Savings      -0.0622      0.114     -0.546      0.588      -0.292       0.168
# Imports         0.1405      0.257      0.547      0.587      -0.379       0.660
# Inflation       0.0202      0.032      0.626      0.535      -0.045       0.086
# Remittances    -0.3731      0.401     -0.930      0.358      -1.184       0.438
# U               0.2817      0.555      0.507      0.615      -0.841       1.405
# Reserve        -0.0662      0.017     -3.932      0.000      -0.100      -0.032
# FDII            2.8210      1.667      1.692      0.099      -0.552       6.194
# FDIO           -1.8163      7.064     -0.257      0.798     -16.105      12.472
# Industry        0.4656      0.166      2.809      0.008       0.130       0.801
# ==============================================================================
# Omnibus:                       14.398   Durbin-Watson:                   2.629
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               53.813
# Skew:                           0.312   Prob(JB):                     2.06e-12
# Kurtosis:                       7.945   Cond. No.                     1.19e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.68e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
lm=smf.ols(formula="GDP~Industry+Reserve",data=df).fit()
lm.rsquared
# Out:
# 0.6097225728639706

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
#Ridge Regression Model
ridgeReg = Ridge(alpha=0.001)

ridgeReg.fit(xtrain,ytrain)
print(sqrt(mean_squared_error(ytrain, ridgeReg.predict(xtrain))))
print(sqrt(mean_squared_error(ytest, ridgeReg.predict(xtest))))
print('R2 Value/Coefficient of Determination: {}'.format(ridgeReg.score(xtest, ytest)))
# Out:
# 1.1559846111929115
# 3.7261494689964954
# R2 Value/Coefficient of Determination: -0.670842546429929

# %% [markdown]
# ### LASSO REGRESSION

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import RepeatedKFold
lassoreg = Lasso(alpha=0.001)
Lasso.fit(xtrain,ytrain)
print(sqrt(mean_squared_error(ytrain, Lasso.predict(xtrain))))
print(sqrt(mean_squared_error(ytest, Lasso.predict(xtest))))
print('R2 Value/Coefficient of Determination: {}'.format(Lasso.score(xtest, ytest)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12392\994880629.py in ?()
#       1 from sklearn.linear_model import Lasso
#       2 from sklearn.model_selection import RepeatedKFold
#       3 lassoreg = Lasso(alpha=0.001)
# ----> 4 Lasso.fit(xtrain,ytrain)
#       5 print(sqrt(mean_squared_error(ytrain, Lasso.predict(xtrain))))
#       6 print(sqrt(mean_squared_error(ytest, Lasso.predict(xtest))))
#       7 print('R2 Value/Coefficient of Determination: {}'.format(Lasso.score(xtest, ytest)))
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1140                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141             )
#    1142
#    1143             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144                 estimator._validate_params()
#    1145
#    1146             with config_context(
#    1147                 skip_parameter_validation=(
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_validate_params'
